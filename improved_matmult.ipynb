# %%
# it takes 7.59302 s for the nested for-loop to execute
# after optimization (using np.linalg.matmul(x, y)) it takes only 0.021208 s

# %%
pip install --user line__profiler

# %%
#Load the line_profiler Extension in Jupyter. This enables the %lprun magic command.
# %load_ext line_profiler

# %%
# Program to multiply two matrices using nested loops
import random

# %%
# NxN matrix
#Wrap the code inside a function so that it can be profiled later.
N = 250
X = []
def Xmatrix(N):
    for i in range(N):
        X.append([random.randint(0,100) for r in range(N)])

# %%
#pass the N parameter to the function and then call %lprun
# %lprun -f Xmatrix Xmatrix(N)
# Out:
# Timer unit: 1e-07 s
#
# Total time: 0.291056 s
# File: C:\Users\arezu\AppData\Local\Temp\ipykernel_4120\2361233442.py
# Function: Xmatrix at line 5
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ...
#      5                                           def Xmatrix(N):
#      6       251        795.0      3.2      0.0      for i in range(N):
#      7     62750    2909761.0     46.4    100.0          X.append([random.randint(0,100) for r in range(N)])

# %%
# Nx(N+1) matrix
Y = []
def Ymatrix(N):
    for i in range(N):
        Y.append([random.randint(0,100) for r in range(N+1)])

# %%
N = 250
# %lprun -f Ymatrix Ymatrix(N)
# Out:
# Timer unit: 1e-07 s
#
# Total time: 0.281701 s
# File: C:\Users\arezu\AppData\Local\Temp\ipykernel_4120\2592418938.py
# Function: Ymatrix at line 3
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ...
#      3                                           def Ymatrix(N):
#      4       251        711.0      2.8      0.0      for i in range(N):
#      5     63000    2816304.0     44.7    100.0          Y.append([random.randint(0,100) for r in range(N+1)])

# %%
# result is Nx(N+1)
result = []
def Rmatrix(N):
    for i in range(N):
        result.append([0] * (N+1))

# %%
N = 250
# %lprun -f Rmatrix Rmatrix(N)
# Out:
# Timer unit: 1e-07 s
#
# Total time: 0.000491 s
# File: C:\Users\arezu\AppData\Local\Temp\ipykernel_4120\1068546426.py
# Function: Rmatrix at line 3
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ...
#      3                                           def Rmatrix(N):
#      4       251        841.0      3.4     17.1      for i in range(N):
#      5       250       4069.0     16.3     82.9          result.append([0] * (N+1))

# %%
def iterat():
    # iterate through rows of X
    for i in range(len(X)):
        # iterate through columns of Y
        for j in range(len(Y[0])):
            # iterate through rows of Y
            for k in range(len(Y)):
                result[i][j] += X[i][k] * Y[k][j]

# %%
# %lprun -f iterat iterat()
# Out:
# Timer unit: 1e-07 s
#
# Total time: 7.89599 s
# File: C:\Users\arezu\AppData\Local\Temp\ipykernel_4120\957569867.py
# Function: iterat at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ...
#      1                                           def iterat():
#      2                                               # iterate through rows of X
#      3       251        888.0      3.5      0.0      for i in range(len(X)):
#      4                                                   # iterate through columns of Y
#      5     63000     145556.0      2.3      0.2          for j in range(len(Y[0])):
#      6                                                       # iterate through rows of Y
#      7  15750250   32764167.0      2.1     41.5              for k in range(len(Y)):
#      8  15687500   46049283.0      2.9     58.3                  result[i][j] += X[i][k] * Y[k][j]

# %%
import numpy as np
def my_matmult():
    matmult = np.linalg.matmul(X, Y)
#print(matmult)

# %%
# %lprun -f my_matmult my_matmult()
# Out:
# Timer unit: 1e-07 s
#
# Total time: 0.021208 s
# File: C:\Users\arezu\AppData\Local\Temp\ipykernel_4120\2584964047.py
# Function: my_matmult at line 2
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ...
#      2                                           def my_matmult():
#      3         1     212080.0 212080.0    100.0      matmult = np.linalg.matmul(X, Y)

# %%
def resfunc():
    for r in result:
        print(r)

# %%
# %lprun -f resfunc resfunc()
# Out:
# [648841, 617764, 640720, 646933, 617341, 600895, 607184, 589839, 665501, 626416, 667153, 680677, 597437, 671959, 611169, 635630, 603329, 657337, 663712, 641159, 612441, 642292, 607762, 632452, 641273, 609056, 610781, 691263, 668392, 642838, 651658, 602183, 591618, 630404, 670582, 638631, 644213, 642075, 623147, 641481, 634773, 625074, 627865, 600023, 663178, 651572, 656653, 651106, 633074, 640635, 647068, 629935, 607650, 593474, 581800, 593770, 619802, 658957, 648528, 655163, 643878, 665845, 641722, 615166, 678098, 619488, 638032, 650401, 656029, 664954, 651488, 670011, 651366, 618715, 647861, 633833, 627546, 642308, 639432, 637805, 602754, 649786, 680949, 614994, 622731, 683794, 619263, 596827, 646464, 644731, 616341, 654213, 617317, 611568, 623552, 667765, 642016, 586554, 649223, 580325, 576722, 663512, 643590, 657848, 637615, 613080, 632451, 600309, 654504, 588394, 611640, 681507, 684775, 594959, 651378, 634323, 626759, 579718, 625859, 609992, 666433, 655187, 641329, 606666, 60727
# ...
